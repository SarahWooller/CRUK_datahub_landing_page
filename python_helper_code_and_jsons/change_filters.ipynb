# %%
import os
import json

# %%
from typing import Dict, Any, List, Optional

class TreeNode:
    """
    Represents a single node in the hierarchical tree structure.
    """
    def __init__(
        self,
        id: str,
        label: str,
        category: str,
        primaryGroup: str,
        description: str,
        children: Optional[List['TreeNode']] = None,
    ):
        """
        Initializes a new tree node with data attributes.

        Args:
            id (str): The unique identifier for the node.
            label (str): The human-readable label or name.
            category (str): The category of the node.
            primaryGroup (str): The primary group classification.
            children (Optional[List['TreeNode']]): A list of child TreeNode objects.
        """
        self.id = id
        self.label = label
        self.category = category
        self.primaryGroup = primaryGroup
        self.description = description
        self.children: List['TreeNode'] = children if children is not None else []

    def __repr__(self):
        """
        Provides a string representation for debugging.
        """
        return f"TreeNode(id='{self.id}', label='{self.label}', children={len(self.children)})"

    def get_child(self, label):
        for child in self.children:
            if child.label == label:
                return child
        

    def add_children(self, labels, descriptions):
        for i, label in enumerate(labels):
            child = TreeNode(id='0_2_3_4', 
                            label=label, 
                            category=self.label, 
                            primaryGroup=self.category, 
                            description = descriptions[i])
            self.children.append(child)
        

    def print_tree(self, level=0):
        """
        Recursively prints the structure of the tree.
        """
        indent = "  " * level
        print(f"{indent}- {self.label} (ID: {self.id})")
        for child in self.children:
            child.print_tree(level + 1)

# %%
def build_dict(tree: TreeNode) -> dict:
    "Recursively builds the new dictionary from the tree"

    dictionary = {}
    for label in ["id", "label", "category", "primaryGroup"]:
        dictionary[label] = getattr(tree, label)
    if tree.children:
        dictionary["children"] = dict([(child.id, build_dict(child)) for child in tree.children])
    return dictionary

# %%
def build_tree(data: Dict[str, Any]) -> TreeNode:
    """
    Recursively builds the TreeNode structure from the raw dictionary data.

    Args:
        data (Dict[str, Any]): The raw dictionary data for a single node.

    Returns:
        TreeNode: The resulting object-oriented tree node.
    """
    # Extract core attributes
    node_id = data.get('id', '')
    label = data.get('label', '')
    category = data.get('category', '')
    primaryGroup = data.get('primaryGroup', 'cancer-type')
    description = data.get('description', '')

    # Initialize the current node
    current_node = TreeNode(
        id=node_id,
        label=label,
        category=category,
        primaryGroup=primaryGroup,
        description=description
    )

    # Check for children and recurse
    raw_children = data.get('children', {})
    if raw_children and isinstance(raw_children, dict):
        # Iterate over the values (the child dictionaries)
        for child_dict in raw_children.values():
            # Recursively build the child node
            child_node = build_tree(child_dict)
            current_node.children.append(child_node)

    return current_node

# %%
dummy_path = "../src/utils/dummy_data"
utils_path = "../src/utils"

# %%
assert(os.path.isdir(dummy_path))

# %%
with open(os.path.join(utils_path, "longer_filter_data.js")) as f:
    filters = eval("".join(f.read().split("\n")[1:-1])[:-1])

# %%
cancer_tree = build_tree(filters["0_0"])
access_tree = build_tree(filters["0_1"])

# %%
data_tree = build_tree(filters["0_2"])

# %%
def pop_label(node, label):
    for i in range(len(node.children)):
        if node.children[i].label == label:
            node.children.pop(i)
            return node
    return node

# %%
data_tree.print_tree()
# Out:
# - dataType (ID: 0_2)
#   - Biobank Samples (ID: 0_2_0)
#     - Material type (ID: 0_2_0_0)
#       - Bloods  (ID: 0_2_0_0_0)
#       - Cells - eg cell lines (ID: 0_2_0_0_1)
#       - Genetic material (ID: 0_2_0_0_2)
#       - Other Fluids - eg urine (ID: 0_2_0_0_3)
#       - Organoids (ID: 0_2_0_0_4)
#       - Tissues - eg Bone marrow aspirate (ID: 0_2_0_0_5)
#       - Other - eg swab (ID: 0_2_0_0_6)
#     - State (ID: 0_2_0_1)
#       - Malignant (ID: 0_2_0_1_0)
#       - Normal (ID: 0_2_0_1_1)
#       - Pre-cancerous (ID: 0_2_0_1_2)
#   - In Vitro Study (ID: 0_2_1)
#     - Model (ID: 0_2_1_0)
#       - Organ on a Chip (ID: 0_2_1_0_0)
#       - 3D organoid (including on a chip) (ID: 0_2_1_0_1)
#       - Organ slice (ID: 0_2_1_0_2)
#     - Cell Source (ID: 0_2_1_1)
#       - Immortalised cell-line (ID: 0_2_1_1_0)
#       - Patient derived (ID: 0_2_1_1_1)
#       - Model Organism derived (ID: 0_2_1_1_2)
#     - Treatment (ID: 0_2_1_2)
#       - Cell and cell-derived treatment (ID: 0_2_1_2_0)
#       - Gene knock-down (ID: 0_2_1_2_1)
#       - Medication (ID: 0_2_1_2_2)
#       - Radiation (ID: 0_2_1_2_3)
#   - Model Organism (ID: 0_2_2)
#     - Organism (ID: 0_2_2_0)
#       - Chicken (ID: 0_2_2_0_0)
#       - Dog (ID: 0_2_2_0_1)
#       - Fruit fly (ID: 0_2_2_0_2)
#       - Mouse (ID: 0_2_2_0_3)
#       - Rabbit (ID: 0_2_2_0_4)
#       - Rat (ID: 0_2_2_0_5)
#       - Saccharomyces cerevisiae (ID: 0_2_2_0_6)
#       - Schizosaccharomyces pombe (ID: 0_2_2_0_7)
#     - Organism preparation (ID: 0_2_2_1)
#       - Genetically engineered (ID: 0_2_2_1_0)
#       - Immuno-compromised (ID: 0_2_2_1_1)
#       - Patient-Derived xenograft (ID: 0_2_2_1_2)
#       - Syngeneic (ID: 0_2_2_1_3)
#     - Biopsy & Lab Results (ID: 0_2_2_2)
#       - Biomarkers (ID: 0_2_2_2_0)
#       - Flow Cytometry (ID: 0_2_2_2_1)
#       - Immunohistochemistry (ID: 0_2_2_2_2)
#     - Imaging Data (ID: 0_2_2_3)
#       - Bioluminescence Imaging (ID: 0_2_2_3_0)
#       - Fluorescence Imaging (ID: 0_2_2_3_1)
#       - Magnetic Resonance Imaging (ID: 0_2_2_3_2)
#       - Medical photography (ID: 0_2_2_3_3)
#       - Microscopy (ID: 0_2_2_3_4)
#       - Nuclear medicine imaging (ID: 0_2_2_3_5)
#       - Radiographic imaging (ID: 0_2_2_3_6)
#       - Ultrasonography (ID: 0_2_2_3_7)
#     - Longitudinal Follow up (ID: 0_2_2_4)
#       - Behavioural data (ID: 0_2_2_4_0)
#       - Clinical observations (ID: 0_2_2_4_1)
#       - Response outcomes (ID: 0_2_2_4_2)
#       - Side effects (ID: 0_2_2_4_3)
#       - Survival data (ID: 0_2_2_4_4)
#     - Multi-omic Data (ID: 0_2_2_5)
#       - Circulating tumour cells (ID: 0_2_2_5_0)
#       - Circulating tumour DNA (ID: 0_2_2_5_1)
#       - Copy Number Variations (ID: 0_2_2_5_2)
#       - Epigenetic Data (ID: 0_2_2_5_3)
#       - Exosomes/Genomes (ID: 0_2_2_5_4)
#       - Fusion Genes (ID: 0_2_2_5_5)
#       - Germline Mutations (ID: 0_2_2_5_6)
#       - Metabolomics (ID: 0_2_2_5_7)
#       - Protein expression profiles (ID: 0_2_2_5_8)
#       - RNA Sequence Expression Profile (ID: 0_2_2_5_9)
#       - Single-cell (ID: 0_2_2_5_10)
#       - Somatic Mutations (ID: 0_2_2_5_11)
#       - Spatial Biology Data (ID: 0_2_2_5_12)
#     - Treatments (ID: 0_2_2_6)
#       - Medication (ID: 0_2_2_6_0)
#       - Cell and cell-derived treatments (ID: 0_2_2_6_1)
#       - Micro-biome alterations (ID: 0_2_2_6_2)
#       - Organ resection and other ablations (ID: 0_2_2_6_3)
#       - Radiotherapies (ID: 0_2_2_6_4)
#   - Patient study (ID: 0_2_3)
#     - Background (ID: 0_2_3_0)
#       - Child and Young Person (ID: 0_2_3_0_0)
#       - Seniors (ID: 0_2_3_0_1)
#       - Demographic (ID: 0_2_3_0_2)
#       - Family history (ID: 0_2_3_0_3)
#       - Lifestyle (ID: 0_2_3_0_4)
#       - Quality of life (eg Education and/or employment) (ID: 0_2_3_0_5)
#     - Biopsy Reports and Lab Results (ID: 0_2_3_1)
#       - Biomarkers (ID: 0_2_3_1_0)
#       - Complete blood count (ID: 0_2_3_1_1)
#       - H&E-stained tissue microarrays (ID: 0_2_3_1_2)
#       - Immunohistochemistry (ID: 0_2_3_1_3)
#       - Kidney function tests (ID: 0_2_3_1_4)
#       - Liver function tests (ID: 0_2_3_1_5)
#       - Other bodily fluid analyses (ID: 0_2_3_1_6)
#       - Tumour details (ID: 0_2_3_1_7)
#       - Urine tests (ID: 0_2_3_1_8)
#     - Imaging Data (ID: 0_2_3_2)
#       - Bioluminescence Imaging (ID: 0_2_3_2_0)
#       - Fluorescence Imaging (ID: 0_2_3_2_1)
#       - Magnetic Resonance Imaging (ID: 0_2_3_2_2)
#       - Medical photography (ID: 0_2_3_2_3)
#       - Microscopy (ID: 0_2_3_2_4)
#       - Nuclear medicine imaging (ID: 0_2_3_2_5)
#       - Radiographic imaging (ID: 0_2_3_2_6)
#       - Ultrasonography (ID: 0_2_3_2_7)
#     - Longitudinal Follow up (ID: 0_2_3_3)
#       - Patient-Reported Outcomes (ID: 0_2_3_3_0)
#       - Response outcomes (ID: 0_2_3_3_1)
#       - Side effects (ID: 0_2_3_3_2)
#       - Survival data (ID: 0_2_3_3_3)
#     - Multi-omic Data (ID: 0_2_3_4)
#       - Circulating tumour cells (ID: 0_2_3_4_0)
#       - Circulating tumour DNA (ID: 0_2_3_4_1)
#       - Copy Number Variations (ID: 0_2_3_4_2)
#       - Epigenetic Data (ID: 0_2_3_4_3)
#       - Exosomes/Genomes (ID: 0_2_3_4_4)
#       - Fusion Genes (ID: 0_2_3_4_5)
#       - Germline Mutations (ID: 0_2_3_4_6)
#       - Metabolomics (ID: 0_2_3_4_7)
#       - Protein expression profiles (ID: 0_2_3_4_8)
#       - RNA Sequence Expression Profile (ID: 0_2_3_4_9)
#       - Single-cell (ID: 0_2_3_4_10)
#       - Somatic Mutations (ID: 0_2_3_4_11)
#       - Spatial Biology Data (ID: 0_2_3_4_12)
#     - Treatments (ID: 0_2_3_5)
#       - Medication (ID: 0_2_3_5_0)
#       - Organ resection and other ablations (ID: 0_2_3_5_1)
#       - Radiotherapies (ID: 0_2_3_5_2)
#     - Clinical Trial (ID: 0_2_3_6)
#       - Phase 0 (ID: 0_2_3_6_0)
#       - Phase 1 (ID: 0_2_3_6_1)
#       - Phase 2 (ID: 0_2_3_6_2)
#       - Phase 3 (ID: 0_2_3_6_3)
#       - Phase 4 (ID: 0_2_3_6_4)
#   - Techniques (ID: 0_2_4)
#     - Computational Model (ID: 0_2_4_0)
#     - Crystallography (ID: 0_2_4_1)
#     - Spectroscopy (ID: 0_2_4_2)
#     - Mechanobiology (ID: 0_2_4_3)
#     - Nanomaterials (ID: 0_2_4_4)

# %%
model = data_tree.get_child("Model Organism")

# %%
patient = data_tree.get_child("Patient study")
multi = patient.get_child("Multi-omic Data")
image = patient.get_child("Imaging Data")

# %%
techniques = data_tree.get_child("Techniques")
co,cr,sp, me, na = techniques.children

# %%
techniques.children = [co, cr,image, me, multi, na, sp]

# %%
for node in [patient, model]:
    for label in ["Multi-omic Data", "Imaging Data"]:
        node = pop_label(node, label)

# %%
for node in [multi, image]:
    node.category = techniques.label
    node.primaryGroup = techniques.label

# %%
data_tree = change_id(data_tree, data_tree.id)

# %%
data_tree.print_tree()
# Out:
# - dataType (ID: 0_2)
#   - Biobank Samples (ID: 0_2_0)
#     - Material type (ID: 0_2_0_0)
#       - Bloods  (ID: 0_2_0_0_0)
#       - Cells - eg cell lines (ID: 0_2_0_0_1)
#       - Genetic material (ID: 0_2_0_0_2)
#       - Other Fluids - eg urine (ID: 0_2_0_0_3)
#       - Organoids (ID: 0_2_0_0_4)
#       - Tissues - eg Bone marrow aspirate (ID: 0_2_0_0_5)
#       - Other - eg swab (ID: 0_2_0_0_6)
#     - State (ID: 0_2_0_1)
#       - Malignant (ID: 0_2_0_1_0)
#       - Normal (ID: 0_2_0_1_1)
#       - Pre-cancerous (ID: 0_2_0_1_2)
#   - In Vitro Study (ID: 0_2_1)
#     - Model (ID: 0_2_1_0)
#       - Organ on a Chip (ID: 0_2_1_0_0)
#       - 3D organoid (including on a chip) (ID: 0_2_1_0_1)
#       - Organ slice (ID: 0_2_1_0_2)
#     - Cell Source (ID: 0_2_1_1)
#       - Immortalised cell-line (ID: 0_2_1_1_0)
#       - Patient derived (ID: 0_2_1_1_1)
#       - Model Organism derived (ID: 0_2_1_1_2)
#     - Treatment (ID: 0_2_1_2)
#       - Cell and cell-derived treatment (ID: 0_2_1_2_0)
#       - Gene knock-down (ID: 0_2_1_2_1)
#       - Medication (ID: 0_2_1_2_2)
#       - Radiation (ID: 0_2_1_2_3)
#   - Model Organism (ID: 0_2_2)
#     - Organism (ID: 0_2_2_0)
#       - Chicken (ID: 0_2_2_0_0)
#       - Dog (ID: 0_2_2_0_1)
#       - Fruit fly (ID: 0_2_2_0_2)
#       - Mouse (ID: 0_2_2_0_3)
#       - Rabbit (ID: 0_2_2_0_4)
#       - Rat (ID: 0_2_2_0_5)
#       - Saccharomyces cerevisiae (ID: 0_2_2_0_6)
#       - Schizosaccharomyces pombe (ID: 0_2_2_0_7)
#     - Organism preparation (ID: 0_2_2_1)
#       - Genetically engineered (ID: 0_2_2_1_0)
#       - Immuno-compromised (ID: 0_2_2_1_1)
#       - Patient-Derived xenograft (ID: 0_2_2_1_2)
#       - Syngeneic (ID: 0_2_2_1_3)
#     - Biopsy & Lab Results (ID: 0_2_2_2)
#       - Biomarkers (ID: 0_2_2_2_0)
#       - Flow Cytometry (ID: 0_2_2_2_1)
#       - Immunohistochemistry (ID: 0_2_2_2_2)
#     - Longitudinal Follow up (ID: 0_2_2_3)
#       - Behavioural data (ID: 0_2_2_3_0)
#       - Clinical observations (ID: 0_2_2_3_1)
#       - Response outcomes (ID: 0_2_2_3_2)
#       - Side effects (ID: 0_2_2_3_3)
#       - Survival data (ID: 0_2_2_3_4)
#     - Treatments (ID: 0_2_2_4)
#       - Medication (ID: 0_2_2_4_0)
#       - Cell and cell-derived treatments (ID: 0_2_2_4_1)
#       - Micro-biome alterations (ID: 0_2_2_4_2)
#       - Organ resection and other ablations (ID: 0_2_2_4_3)
#       - Radiotherapies (ID: 0_2_2_4_4)
#   - Patient study (ID: 0_2_3)
#     - Background (ID: 0_2_3_0)
#       - Child and Young Person (ID: 0_2_3_0_0)
#       - Seniors (ID: 0_2_3_0_1)
#       - Demographic (ID: 0_2_3_0_2)
#       - Family history (ID: 0_2_3_0_3)
#       - Lifestyle (ID: 0_2_3_0_4)
#       - Quality of life (eg Education and/or employment) (ID: 0_2_3_0_5)
#     - Biopsy Reports and Lab Results (ID: 0_2_3_1)
#       - Biomarkers (ID: 0_2_3_1_0)
#       - Complete blood count (ID: 0_2_3_1_1)
#       - H&E-stained tissue microarrays (ID: 0_2_3_1_2)
#       - Immunohistochemistry (ID: 0_2_3_1_3)
#       - Kidney function tests (ID: 0_2_3_1_4)
#       - Liver function tests (ID: 0_2_3_1_5)
#       - Other bodily fluid analyses (ID: 0_2_3_1_6)
#       - Tumour details (ID: 0_2_3_1_7)
#       - Urine tests (ID: 0_2_3_1_8)
#     - Longitudinal Follow up (ID: 0_2_3_2)
#       - Patient-Reported Outcomes (ID: 0_2_3_2_0)
#       - Response outcomes (ID: 0_2_3_2_1)
#       - Side effects (ID: 0_2_3_2_2)
#       - Survival data (ID: 0_2_3_2_3)
#     - Treatments (ID: 0_2_3_3)
#       - Medication (ID: 0_2_3_3_0)
#       - Organ resection and other ablations (ID: 0_2_3_3_1)
#       - Radiotherapies (ID: 0_2_3_3_2)
#     - Clinical Trial (ID: 0_2_3_4)
#       - Phase 0 (ID: 0_2_3_4_0)
#       - Phase 1 (ID: 0_2_3_4_1)
#       - Phase 2 (ID: 0_2_3_4_2)
#       - Phase 3 (ID: 0_2_3_4_3)
#       - Phase 4 (ID: 0_2_3_4_4)
#   - Techniques (ID: 0_2_4)
#     - Computational Model (ID: 0_2_4_0)
#     - Crystallography (ID: 0_2_4_1)
#     - Imaging Data (ID: 0_2_4_2)
#       - Bioluminescence Imaging (ID: 0_2_4_2_0)
#       - Fluorescence Imaging (ID: 0_2_4_2_1)
#       - Magnetic Resonance Imaging (ID: 0_2_4_2_2)
#       - Medical photography (ID: 0_2_4_2_3)
#       - Microscopy (ID: 0_2_4_2_4)
#       - Nuclear medicine imaging (ID: 0_2_4_2_5)
#       - Radiographic imaging (ID: 0_2_4_2_6)
#       - Ultrasonography (ID: 0_2_4_2_7)
#     - Mechanobiology (ID: 0_2_4_3)
#     - Multi-omic Data (ID: 0_2_4_4)
#       - Circulating tumour cells (ID: 0_2_4_4_0)
#       - Circulating tumour DNA (ID: 0_2_4_4_1)
#       - Copy Number Variations (ID: 0_2_4_4_2)
#       - Epigenetic Data (ID: 0_2_4_4_3)
#       - Exosomes/Genomes (ID: 0_2_4_4_4)
#       - Fusion Genes (ID: 0_2_4_4_5)
#       - Germline Mutations (ID: 0_2_4_4_6)
#       - Metabolomics (ID: 0_2_4_4_7)
#       - Protein expression profiles (ID: 0_2_4_4_8)
#       - RNA Sequence Expression Profile (ID: 0_2_4_4_9)
#       - Single-cell (ID: 0_2_4_4_10)
#       - Somatic Mutations (ID: 0_2_4_4_11)
#       - Spatial Biology Data (ID: 0_2_4_4_12)
#     - Nanomaterials (ID: 0_2_4_5)
#     - Spectroscopy (ID: 0_2_4_6)

# %%
multi.id
# Out:
# '0_2_4_4'

# %%
omics_node = TreeNode(id=multi.id, 
                      label=multi.label, 
                      category=multi.category, 
                      primaryGroup=multi.primaryGroup, 
                      description="Omic techniques such as genomics / proteomics" )

# %%
layers = ["Biological molecules (eg DNA)", "Source", "Spatial resolution"]
descriptions = ["genomics/proteomics etc", "eg. control/tumour", "single cell/spatial etc"]
omics_node.add_children(layers, descriptions)

# %%
omics_node.children
# Out:
# [TreeNode(id='0_2_3_4_0', label='Biological molecules (eg DNA)', children=0),
#  TreeNode(id='0_2_3_4_1', label='Source', children=0),
#  TreeNode(id='0_2_3_4_2', label='Spatial resolution', children=0)]

# %%
sources = ["Control", "Liquid Biopsy", "Other", "Tumour"]
descriptions = ["healthy tissue", "circulating tumour cells (CTCs), exosomes etc.", "e.g. environmental", "primary and secondary tumours"]

omics_node.get_child("Source").add_children(sources,descriptions)

bios = sorted(["Proteomics", "Transcriptomics", "Epigenomics", "Metabolomics", "Metagenomics", "Genomics"])

descriptions = ["chemical modifications to DNA/histones",
                "exomes/genomes",                 
                "small molecules (sugars, amino acids) produced by metabolism",
                "genetic material from multiple organisms (usually microbes) living together",
                "functional molecules that carry out cellular processes",
                "RNA transcripts of DNA",
                ]

omics_node.get_child("Biological molecules (eg DNA)").add_children(bios,descriptions)

layers = ["bulk", "single cell", "spatial"]
descriptions = ["tumour average - may include non-tumour cells", "specific cells", "includes positional information"]

omics_node.get_child('Spatial resolution').add_children(layers, descriptions)

# %%
omics_node = change_id(omics_node, omics_node.id)

# %%
omics_node.print_tree()
# Out:
# - Multi-omic Data (ID: 0_2_4_4)
#   - Biological molecules (eg DNA) (ID: 0_2_4_4_0)
#     - Epigenomics (ID: 0_2_4_4_0_0)
#     - Genomics (ID: 0_2_4_4_0_1)
#     - Metabolomics (ID: 0_2_4_4_0_2)
#     - Metagenomics (ID: 0_2_4_4_0_3)
#     - Proteomics (ID: 0_2_4_4_0_4)
#     - Transcriptomics (ID: 0_2_4_4_0_5)
#   - Source (ID: 0_2_4_4_1)
#     - Control (ID: 0_2_4_4_1_0)
#     - Liquid Biopsy (ID: 0_2_4_4_1_1)
#     - Other (ID: 0_2_4_4_1_2)
#     - Tumour (ID: 0_2_4_4_1_3)
#   - Spatial resolution (ID: 0_2_4_4_2)
#     - bulk (ID: 0_2_4_4_2_0)
#     - single cell (ID: 0_2_4_4_2_1)
#     - spatial (ID: 0_2_4_4_2_2)

# %%
data_tree.get_child('Techniques').children[-3] = omics_node

# %%
data_tree = change_id(data_tree, data_tree.id)

# %%
data_tree.print_tree()
# Out:
# - dataType (ID: 0_2)
#   - Biobank Samples (ID: 0_2_0)
#     - Material type (ID: 0_2_0_0)
#       - Bloods  (ID: 0_2_0_0_0)
#       - Cells - eg cell lines (ID: 0_2_0_0_1)
#       - Genetic material (ID: 0_2_0_0_2)
#       - Other Fluids - eg urine (ID: 0_2_0_0_3)
#       - Organoids (ID: 0_2_0_0_4)
#       - Tissues - eg Bone marrow aspirate (ID: 0_2_0_0_5)
#       - Other - eg swab (ID: 0_2_0_0_6)
#     - State (ID: 0_2_0_1)
#       - Malignant (ID: 0_2_0_1_0)
#       - Normal (ID: 0_2_0_1_1)
#       - Pre-cancerous (ID: 0_2_0_1_2)
#   - In Vitro Study (ID: 0_2_1)
#     - Model (ID: 0_2_1_0)
#       - Organ on a Chip (ID: 0_2_1_0_0)
#       - 3D organoid (including on a chip) (ID: 0_2_1_0_1)
#       - Organ slice (ID: 0_2_1_0_2)
#     - Cell Source (ID: 0_2_1_1)
#       - Immortalised cell-line (ID: 0_2_1_1_0)
#       - Patient derived (ID: 0_2_1_1_1)
#       - Model Organism derived (ID: 0_2_1_1_2)
#     - Treatment (ID: 0_2_1_2)
#       - Cell and cell-derived treatment (ID: 0_2_1_2_0)
#       - Gene knock-down (ID: 0_2_1_2_1)
#       - Medication (ID: 0_2_1_2_2)
#       - Radiation (ID: 0_2_1_2_3)
#   - Model Organism (ID: 0_2_2)
#     - Organism (ID: 0_2_2_0)
#       - Chicken (ID: 0_2_2_0_0)
#       - Dog (ID: 0_2_2_0_1)
#       - Fruit fly (ID: 0_2_2_0_2)
#       - Mouse (ID: 0_2_2_0_3)
#       - Rabbit (ID: 0_2_2_0_4)
#       - Rat (ID: 0_2_2_0_5)
#       - Saccharomyces cerevisiae (ID: 0_2_2_0_6)
#       - Schizosaccharomyces pombe (ID: 0_2_2_0_7)
#     - Organism preparation (ID: 0_2_2_1)
#       - Genetically engineered (ID: 0_2_2_1_0)
#       - Immuno-compromised (ID: 0_2_2_1_1)
#       - Patient-Derived xenograft (ID: 0_2_2_1_2)
#       - Syngeneic (ID: 0_2_2_1_3)
#     - Biopsy & Lab Results (ID: 0_2_2_2)
#       - Biomarkers (ID: 0_2_2_2_0)
#       - Flow Cytometry (ID: 0_2_2_2_1)
#       - Immunohistochemistry (ID: 0_2_2_2_2)
#     - Longitudinal Follow up (ID: 0_2_2_3)
#       - Behavioural data (ID: 0_2_2_3_0)
#       - Clinical observations (ID: 0_2_2_3_1)
#       - Response outcomes (ID: 0_2_2_3_2)
#       - Side effects (ID: 0_2_2_3_3)
#       - Survival data (ID: 0_2_2_3_4)
#     - Treatments (ID: 0_2_2_4)
#       - Medication (ID: 0_2_2_4_0)
#       - Cell and cell-derived treatments (ID: 0_2_2_4_1)
#       - Micro-biome alterations (ID: 0_2_2_4_2)
#       - Organ resection and other ablations (ID: 0_2_2_4_3)
#       - Radiotherapies (ID: 0_2_2_4_4)
#   - Patient study (ID: 0_2_3)
#     - Background (ID: 0_2_3_0)
#       - Child and Young Person (ID: 0_2_3_0_0)
#       - Seniors (ID: 0_2_3_0_1)
#       - Demographic (ID: 0_2_3_0_2)
#       - Family history (ID: 0_2_3_0_3)
#       - Lifestyle (ID: 0_2_3_0_4)
#       - Quality of life (eg Education and/or employment) (ID: 0_2_3_0_5)
#     - Biopsy Reports and Lab Results (ID: 0_2_3_1)
#       - Biomarkers (ID: 0_2_3_1_0)
#       - Complete blood count (ID: 0_2_3_1_1)
#       - H&E-stained tissue microarrays (ID: 0_2_3_1_2)
#       - Immunohistochemistry (ID: 0_2_3_1_3)
#       - Kidney function tests (ID: 0_2_3_1_4)
#       - Liver function tests (ID: 0_2_3_1_5)
#       - Other bodily fluid analyses (ID: 0_2_3_1_6)
#       - Tumour details (ID: 0_2_3_1_7)
#       - Urine tests (ID: 0_2_3_1_8)
#     - Longitudinal Follow up (ID: 0_2_3_2)
#       - Patient-Reported Outcomes (ID: 0_2_3_2_0)
#       - Response outcomes (ID: 0_2_3_2_1)
#       - Side effects (ID: 0_2_3_2_2)
#       - Survival data (ID: 0_2_3_2_3)
#     - Treatments (ID: 0_2_3_3)
#       - Medication (ID: 0_2_3_3_0)
#       - Organ resection and other ablations (ID: 0_2_3_3_1)
#       - Radiotherapies (ID: 0_2_3_3_2)
#     - Clinical Trial (ID: 0_2_3_4)
#       - Phase 0 (ID: 0_2_3_4_0)
#       - Phase 1 (ID: 0_2_3_4_1)
#       - Phase 2 (ID: 0_2_3_4_2)
#       - Phase 3 (ID: 0_2_3_4_3)
#       - Phase 4 (ID: 0_2_3_4_4)
#   - Techniques (ID: 0_2_4)
#     - Computational Model (ID: 0_2_4_0)
#     - Crystallography (ID: 0_2_4_1)
#     - Imaging Data (ID: 0_2_4_2)
#       - Bioluminescence Imaging (ID: 0_2_4_2_0)
#       - Fluorescence Imaging (ID: 0_2_4_2_1)
#       - Magnetic Resonance Imaging (ID: 0_2_4_2_2)
#       - Medical photography (ID: 0_2_4_2_3)
#       - Microscopy (ID: 0_2_4_2_4)
#       - Nuclear medicine imaging (ID: 0_2_4_2_5)
#       - Radiographic imaging (ID: 0_2_4_2_6)
#       - Ultrasonography (ID: 0_2_4_2_7)
#     - Mechanobiology (ID: 0_2_4_3)
#     - Multi-omic Data (ID: 0_2_4_4)
#       - Biological molecules (eg DNA) (ID: 0_2_4_4_0)
#         - Epigenomics (ID: 0_2_4_4_0_0)
#         - Genomics (ID: 0_2_4_4_0_1)
#         - Metabolomics (ID: 0_2_4_4_0_2)
#         - Metagenomics (ID: 0_2_4_4_0_3)
#         - Proteomics (ID: 0_2_4_4_0_4)
#         - Transcriptomics (ID: 0_2_4_4_0_5)
#       - Source (ID: 0_2_4_4_1)
#         - Control (ID: 0_2_4_4_1_0)
#         - Liquid Biopsy (ID: 0_2_4_4_1_1)
#         - Other (ID: 0_2_4_4_1_2)
#         - Tumour (ID: 0_2_4_4_1_3)
#       - Spatial resolution (ID: 0_2_4_4_2)
#         - bulk (ID: 0_2_4_4_2_0)
#         - single cell (ID: 0_2_4_4_2_1)
#         - spatial (ID: 0_2_4_4_2_2)
#     - Nanomaterials (ID: 0_2_4_5)
#     - Spectroscopy (ID: 0_2_4_6)

# %%
omics = data_tree.get_child("Techniques").get_child("Multi-omic Data")

bio = omics.get_child('Biological molecules (eg DNA)')
geo = bio.get_child("Genomics")


labels = ["SNVs", "Indels", "CNVs", "Fusion Genes"]
descriptions = ["single base changes", "small insertions or deletions",
                "large scale amplifications/deletions","chromosomal translocations"]

geo.add_children(labels, descriptions)

# %%
geo.print_tree()
# Out:
# - Genomics (ID: 0_2_4_4_0_1)
#   - SNVs (ID: 0_2_4_4_0_1_0)
#   - Indels (ID: 0_2_4_4_0_1_1)
#   - CNVs (ID: 0_2_4_4_0_1_2)
#   - Fusion Genes (ID: 0_2_4_4_0_1_3)

# %%
new_filters = {"0_0" : build_dict(cancer_tree),
               "0_1" : build_dict(access_tree),
               "0_2" : build_dict(data_tree)}

# %%
with open(os.path.join(utils_path, "longer_filter_data.js"), "w") as f:
    f.write("const theFilters =\n")
    json.dump(new_filters, f)
    f.write(";\nexport const filterData = theFilters;")

# %%
data_dictionary = build_dict(data_tree)

# %%
[b.label for b in bio.children]
# Out:
# ['Epigenomics',
#  'Genomics',
#  'Metabolomics',
#  'Metagenomics',
#  'Proteomics',
#  'Transcriptomics']

# %%
filters["0_2"] = data_dictionary

# %%
with open("filters.json", "w") as f:
    json.dump(filters, f)

# %%
def change_id(node, identity):
    node.id = identity
    if not node.children:
        return node
    else:
        old_children = node.children.copy()
        children = []
        for i, child in enumerate(old_children): 
            iden = f"{identity}_{i}"
            child = change_id(child, iden)
            children.append(child)
        node.children = children
    return node

# %%
data_tree = change_id(data_tree, data_tree.id)

# %%
data_tree.children[-1].children[2].children
# Out:
# [TreeNode(id='0_2_4_2_0', label='Bioluminescence Imaging', children=0),
#  TreeNode(id='0_2_4_2_1', label='Fluorescence Imaging', children=0),
#  TreeNode(id='0_2_4_2_2', label='Magnetic Resonance Imaging', children=0),
#  TreeNode(id='0_2_4_2_3', label='Medical photography', children=0),
#  TreeNode(id='0_2_4_2_4', label='Microscopy', children=0),
#  TreeNode(id='0_2_4_2_5', label='Nuclear medicine imaging', children=0),
#  TreeNode(id='0_2_4_2_6', label='Radiographic imaging', children=0),
#  TreeNode(id='0_2_4_2_7', label='Ultrasonography', children=0)]
