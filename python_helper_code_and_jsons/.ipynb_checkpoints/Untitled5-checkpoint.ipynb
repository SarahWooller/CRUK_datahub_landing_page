# %%
import os

# %%
directory = "../docs/assets"
files = [i for i in os.listdir(directory) if i[-3:]==".js"]

# %%
files
# Out:
# ['filterLogic-DitQ8sb5.js',
#  'alt_studies-Dw9Jrsjz.js',
#  'upload-C3Kp_hKi.js',
#  'Introduction-C33Gey56.js',
#  'JustVertFilterApp-BV2Rx11r.js',
#  'longer_filter_data-5oxdC1Yb.js',
#  'useFeedback-bHLs6PkO.js',
#  'upload_project-CXo0lUNW.js',
#  'Header-CRg7lg02.js',
#  'meta-DeywkXdr.js',
#  'just_vert_bar-XIKP9bXo.js',
#  'vert_bar-BSHl4WNl.js',
#  'StudiesSection-BFIOzT6D.js',
#  'main-p_SojNeu.js',
#  'HorFilterApp-CYStQzvV.js',
#  'studies2-ClYglw2T.js',
#  'InstructionsWidget-CeXGCO6K.js',
#  'top_bar-C0D8yUq5.js',
#  'FeedbackWidget-BRoSNDLz.js',
#  'prefix_icon_mapping-DXY8VIJy.js',
#  'filter-setup-edKmeTHo.js',
#  'dashboard-sSdg-D6I.js',
#  'client-BbprRhkc.js']

# %%
changes = [("./sign_in.html", "../sign_in.html"),
          ("./protect_data.html", "../protect_data.html"),
          ("./upload.html", "../upload.html"),
          ("./src/upload.html", "../src/upload.html"), 
          ("./about.html", "../about.html"),]

# %%
for file in files:
    path = os.path.join(directory, file)
    with open(path) as f:
        text = f.read()
    for old,new in changes:
        text = text.replace(old,new)
    with open(path, "w") as f:
        f.write(text)
