# %%
import xml.etree.ElementTree as ET
import pandas as pd

def parse_duo_ontology(file_path):
    # DEFINE THE NAMESPACES USED IN THE RDF/XML FILE
    ns = {
        'owl': 'http://www.w3.org/2002/07/owl#',
        'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#',
        'rdfs': 'http://www.w3.org/2000/01/rdf-schema#',
        'obo': 'http://purl.obolibrary.org/obo/',
        'oboInOwl': 'http://www.geneontology.org/formats/oboInOwl#'
    }

    try:
        tree = ET.parse(file_path)
        root = tree.getroot()
    except Exception as e:
        return f"ERROR PARSING FILE: {e}"

    ontology_data = []

    # SEARCH FOR BOTH CLASSES AND OBJECT PROPERTIES
    tags_to_find = [
        ('owl:Class', 'Class'),
        ('owl:ObjectProperty', 'Property')
    ]

    for tag, category in tags_to_find:
        for item in root.findall(tag, ns):
            # EXTRACT CORE METADATA
            duo_id_elem = item.find('oboInOwl:id', ns)
            label_elem = item.find('rdfs:label', ns)
            def_elem = item.find('obo:IAO_0000115', ns)
            
            # CHECK IF THE TERM IS DEPRECATED
            deprecated = item.find('owl:deprecated', ns)
            if deprecated is not None and deprecated.text.lower() == 'true':
                continue

            # SKIP ANONYMOUS CLASSES (THOSE WITHOUT AN ABOUT ATTRIBUTE OR ID)
            if duo_id_elem is None and label_elem is None:
                continue

            ontology_data.append({
                'ID': duo_id_elem.text if duo_id_elem is not None else 'N/A',
                'TYPE': category,
                'LABEL': label_elem.text if label_elem is not None else 'N/A',
                'DEFINITION': def_elem.text if def_elem is not None else 'NO DEFINITION PROVIDED'
            })

    # CREATE A DATAFRAME AND SORT BY ID
    df = pd.DataFrame(ontology_data)
    df = df.sort_values(by='ID').reset_index(drop=True)
    
    return df

# USAGE
# REPLACE 'duo.owl' WITH THE ACTUAL PATH TO YOUR DOWNLOADED FILE
file_path = '../access.xml'
df_results = parse_duo_ontology(file_path)

# VIEW THE FIRST FEW ROWS
print(df_results.head(20))

# OPTIONAL: SAVE TO A CLEAN EXCEL OR CSV FILE
# df_results.to_csv('duo_table.csv', index=False)
# Out:
#              ID      TYPE                                            LABEL  \
# 0   DUO:0000001     Class                              data use permission
# 1   DUO:0000004     Class                                   no restriction
# 2   DUO:0000005     Class  obsolete general research use and clinical care
# 3   DUO:0000006     Class         health or medical or biomedical research
# 4   DUO:0000007     Class                        disease specific research
# 5   DUO:0000010  Property                                 is restricted to
# 6   DUO:0000011     Class     population origins or ancestry research only
# 7   DUO:0000012     Class                   research specific restrictions
# 8   DUO:0000014     Class                       obsolete research use only
# 9   DUO:0000015     Class                      no general methods research
# 10  DUO:0000016     Class                             genetic studies only
# 11  DUO:0000017     Class                                data use modifier
# 12  DUO:0000018     Class          not for profit, non commercial use only
# 13  DUO:0000019     Class                             publication required
# 14  DUO:0000020     Class                           collaboration required
# 15  DUO:0000021     Class                         ethics approval required
# 16  DUO:0000022     Class                         geographical restriction
# 17  DUO:0000024     Class                           publication moratorium
# 18  DUO:0000025     Class                                time limit on use
# 19  DUO:0000026     Class                        user specific restriction
#
#                                            DEFINITION
# 0   A data item that is used to indicate consent p...
# 1   This data use permission indicates there is no...
# 2   This data use limitation indicates that use is...
# 3   This data use permission indicates that use is...
# 4   This data use permission indicates that use is...
# 5   A is restricted to B iff A is a consent code a...
# 6   This data use permission indicates that use of...
# 7   This data use modifier indicates that use is l...
# 8   This data use limitation indicates that use is...
# 9   This data use modifier indicates that use does...
# 10  This data use modifier indicates that use is l...
# 11  Data use modifiers indicate additional conditi...
# 12  This data use modifier indicates that use of t...
# 13  This data use modifier indicates that requesto...
# 14  This data use modifier indicates that the requ...
# 15  This data use modifier indicates that the requ...
# 16  This data use modifier indicates that use is l...
# 17  This data use modifier indicates that requesto...
# 18  This data use modifier indicates that use is a...
# 19  This data use modifier indicates that use is l...

# %%
df_results.to

# %%
df_results.iloc[:,[2,3]]
# Out:
#                                                 LABEL  \
# 0                                 data use permission
# 1                                      no restriction
# 2     obsolete general research use and clinical care
# 3            health or medical or biomedical research
# 4                           disease specific research
# 5                                    is restricted to
# 6        population origins or ancestry research only
# 7                      research specific restrictions
# 8                          obsolete research use only
# 9                         no general methods research
# 10                               genetic studies only
# 11                                  data use modifier
# 12            not for profit, non commercial use only
# 13                               publication required
# 14                             collaboration required
# 15                           ethics approval required
# 16                           geographical restriction
# 17                             publication moratorium
# 18                                  time limit on use
# 19                          user specific restriction
# 20                       project specific restriction
# 21                   institution specific restriction
# 22                     return to database or resource
# 23                                 method development
# 24                                population research
# 25                                  ancestry research
# 26                              age category research
# 27                           gender category research
# 28                                   research control
# 29                                biomedical research
# 30                                   genetic research
# 31                          drug development research
# 32                          disease category research
# 33                               general research use
# 34                                  clinical care use
# 35  population origins or ancestry research prohib...
# 36               not for profit organisation use only
# 37                            non-commercial use only
# 38                                geographic location
# 39                                disease or disorder
# 40                                              Topic
#
#                                            DEFINITION
# 0   A data item that is used to indicate consent p...
# 1   This data use permission indicates there is no...
# 2   This data use limitation indicates that use is...
# 3   This data use permission indicates that use is...
# 4   This data use permission indicates that use is...
# 5   A is restricted to B iff A is a consent code a...
# 6   This data use permission indicates that use of...
# 7   This data use modifier indicates that use is l...
# 8   This data use limitation indicates that use is...
# 9   This data use modifier indicates that use does...
# 10  This data use modifier indicates that use is l...
# 11  Data use modifiers indicate additional conditi...
# 12  This data use modifier indicates that use of t...
# 13  This data use modifier indicates that requesto...
# 14  This data use modifier indicates that the requ...
# 15  This data use modifier indicates that the requ...
# 16  This data use modifier indicates that use is l...
# 17  This data use modifier indicates that requesto...
# 18  This data use modifier indicates that use is a...
# 19  This data use modifier indicates that use is l...
# 20  This data use modifier indicates that use is l...
# 21  This data use modifier indicates that use is l...
# 22  This data use modifier indicates that the requ...
# 23  An investigation concerning development of met...
# 24  An investigation concerning a specific populat...
# 25  An investigation concerning ancestry or popula...
# 26  An investigation concerning specific age categ...
# 27  An investigation concerning specific gender ca...
# 28  An investigation concerning use of data as ref...
# 29  An investigation concerning health, medical, o...
# 30  Biomedical research concerning genetics (i.e.,...
# 31   Biomedical research concerning drug development.
# 32  Biomedical research research concerning specif...
# 33  This data use permission indicates that use is...
# 34  This data use modifier indicates that use is a...
# 35  This data use modifier indicates use for purpo...
# 36  This data use modifier indicates that use of t...
# 37  This data use modifier indicates that use of t...
# 38                             NO DEFINITION PROVIDED
# 39  A disease is a disposition to undergo patholog...
# 40  A category denoting a rather broad domain or f...

# %%
list(map(list,df_results.loc[df_results.DEFINITION.map(lambda x: "modifier" in x)].iloc[:,[2,3]].values))
# Out:
# [['research specific restrictions',
#   'This data use modifier indicates that use is limited to studies of a certain research type.'],
#  ['no general methods research',
#   'This data use modifier indicates that use does not allow methods development research (e.g., development of software or algorithms).'],
#  ['genetic studies only',
#   'This data use modifier indicates that use is limited to genetic studies only (i.e., studies that include genotype research alone or both genotype and phenotype research, but not phenotype research exclusively)'],
#  ['data use modifier',
#   'Data use modifiers indicate additional conditions for use.'],
#  ['not for profit, non commercial use only',
#   'This data use modifier indicates that use of the data is limited to not-for-profit organizations and not-for-profit use, non-commercial use.'],
#  ['publication required',
#   'This data use modifier indicates that requestor agrees to make results of studies using the data available to the larger scientific community.'],
#  ['collaboration required',
#   'This data use modifier indicates that the requestor must agree to collaboration with the primary study investigator(s).'],
#  ['ethics approval required',
#   'This data use modifier indicates that the requestor must provide documentation of local IRB/ERB approval.'],
#  ['geographical restriction',
#   'This data use modifier indicates that use is limited to within a specific geographic region.'],
#  ['publication moratorium',
#   'This data use modifier indicates that requestor agrees not to publish results of studies until a specific date.'],
#  ['time limit on use',
#   'This data use modifier indicates that use is approved for a specific number of months.'],
#  ['user specific restriction',
#   'This data use modifier indicates that use is limited to use by approved users.'],
#  ['project specific restriction',
#   'This data use modifier indicates that use is limited to use within an approved project.'],
#  ['institution specific restriction',
#   'This data use modifier indicates that use is limited to use within an approved institution.'],
#  ['return to database or resource',
#   'This data use modifier indicates that the requestor must return derived/enriched data to the database/resource.'],
#  ['clinical care use',
#   'This data use modifier indicates that use is allowed for clinical use and care.'],
#  ['population origins or ancestry research prohibited',
#   'This data use modifier indicates use for purposes of population, origin, or ancestry research is prohibited.'],
#  ['not for profit organisation use only',
#   'This data use modifier indicates that use of the data is limited to not-for-profit organizations.'],
#  ['non-commercial use only',
#   'This data use modifier indicates that use of the data is limited to not-for-profit use.']]
