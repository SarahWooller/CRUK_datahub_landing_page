# %%
import pandas as pd

# %%
df = pd.read_csv("access.csv")

# %%
modifiers = df.loc[df.DEFINITION.map(lambda x :"modifier" in x)].iloc[:,[3,4]]
modifiers.index = range(19)

# %%
modifiers.to_csv("modifiers.csv")

# %%
[1,]

# %%
with open("access_info.txt", "w") as g:
    g.write("\n".join([f"{i} {v[0]} - {v[1]}" for i,v in enumerate(list(map(list,df.iloc[:,[3,4]].values)))]))
