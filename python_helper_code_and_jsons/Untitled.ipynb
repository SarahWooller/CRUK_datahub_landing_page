# %%
import json

# %%
with open("../src/utils/tcga_cruk_mappings.json") as f:
    maps = json.load(f)

# %%
with open("../src/utils/labels.json") as f:
    labels = json.load(f)

# %%
cruk_maps = set(maps["CRUK"].keys())

# %%
cruk_labels = set(labels['CRUK'])

# %%
len(cruk_maps & cruk_labels)
# Out:
# 33

# %%
cruk_maps - cruk_labels
# Out:
# {'Esophageal cancer'}

# %%
cruk_labels - cruk_maps
# Out:
# {'Acute lymphoblastic leukaemia (ALL) in children',
#  'Ampullary cancer',
#  'Blood cancers',
#  'Brain tumours in children',
#  'Breast cancer in men',
#  'Cancer of unknown primary (CUP)',
#  'Cancer spread to bone',
#  'Cancer spread to brain',
#  'Cancer spread to liver',
#  'Cancer spread to lung',
#  'Carcinoid',
#  "Children's cancers",
#  'Cholangiocarcinoma',
#  'Chronic lymphocytic leukaemia (CLL)',
#  'Chronic myeloid leukaemia (CML)',
#  'Chronic myelomonocytic leukaemia (CMML)',
#  'Ear cancer',
#  'Endometrial cancer',
#  'Essential Thrombocythaemia (ET)',
#  'Eye cancer',
#  'Follicular dendritic cell sarcoma',
#  'Gallbladder cancer',
#  'Gastro oesophageal junction cancers',
#  'Germ cell tumours',
#  'Gestational trophoblastic disease (GTD)',
#  'Hairy cell leukaemia',
#  'Invasive mole and choriocarcinomas',
#  'Juvenile myelomonocytic leukaemia (JMML)',
#  "Kaposi's sarcoma",
#  'Large bowel and rectal neuroendocrine tumours',
#  'Laryngeal cancer',
# ...
