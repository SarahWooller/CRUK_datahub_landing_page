# %%
# !pwd
# Out:
# /Users/skw24/CRUK/clean_landing/CRUK_datahub_landing_page

# %%
import json

# %%
with open("filter_information.json") as f:
    fi = json.load(f)

# %%
fi[0]
# Out:
# {'id': '0_0_0_0_0_0',
#  'label': 'C00.0 External upper lip',
#  'category': 'C00 Lip',
#  'parent': '0_0_0_0_0',
#  'primaryGroup': 'cancer-type'}

# %%
fid = [i for i in fi if i["id"][:3] == "0_2"]

# %%
fid[1]
# Out:
# {'id': '0_2_0_0_1',
#  'label': 'Cells - eg cell lines',
#  'category': 'Material type',
#  'parent': '0_2_0_0',
#  'primaryGroup': 'data-type'}

# %%
with open("filter_information_data.json", "w") as f:
    json.dump(fid, f)
